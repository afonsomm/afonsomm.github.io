# %% [raw]
# ---
# title: "Intro to PySpark"
# author: "Afonso Magalhães"
# date: "2023-10-15"
# categories: [pyspark, apache spark, distributed computing]
# ---

# %% [markdown]
# # Intro to PySpark

# %%
from pyspark.sql import SparkSession
